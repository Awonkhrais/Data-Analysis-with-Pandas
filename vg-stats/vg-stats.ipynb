# %% [markdown]
# # Data Analysis with Pandas
# # vg-stats data

# %%
import pandas as pd

# %%
df = pd.read_csv('./vgsales.csv')
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ## 1- Which company is the most common video game publisher?

# %%
most_publisher = df['Publisher'].describe().top
most_publisher
# Out:
# 'Electronic Arts'

# %% [markdown]
# ## 2- What’s the most common platform?

# %%
most_paltform = df ['Platform'].describe().top
most_paltform
# Out:
# 'DS'

# %% [markdown]
# ## 3- What about the most common genre?

# %%
most_Genre = df ['Genre'].describe().top
most_Genre
# Out:
# 'Action'

# %% [markdown]
# ## 4- What are the top 20 highest grossing games?

# %%
highest_grossing = df[["Rank","Name" , "Global_Sales"]]
highest_grossing.head(20)
# Out:
#     Rank                                          Name  Global_Sales
# 0      1                                    Wii Sports         82.74
# 1      2                             Super Mario Bros.         40.24
# 2      3                                Mario Kart Wii         35.82
# 3      4                             Wii Sports Resort         33.00
# 4      5                      Pokemon Red/Pokemon Blue         31.37
# 5      6                                        Tetris         30.26
# 6      7                         New Super Mario Bros.         30.01
# 7      8                                      Wii Play         29.02
# 8      9                     New Super Mario Bros. Wii         28.62
# 9     10                                     Duck Hunt         28.31
# 10    11                                    Nintendogs         24.76
# 11    12                                 Mario Kart DS         23.42
# 12    13                   Pokemon Gold/Pokemon Silver         23.10
# ...

# %% [markdown]
# ## 5- For North American video game sales, what’s the median?

# %%
median = df[['NA_Sales']].median()
median
# Out:
# NA_Sales    0.08
# dtype: float64

# %%
NA_med=df['NA_Sales'].median()
top_ten = df[df['NA_Sales'] == NA_med].head(10)
top_ten
# Out:
#       Rank                                               Name Platform  \
# 446    447                                  Dragon Warrior IV      NES
# 497    498        World Soccer Winning Eleven 7 International      PS2
# 1617  1619                             Farming Simulator 2015       PC
# 1926  1928                          Pro Evolution Soccer 2008     X360
# 2067  2069  Winning Eleven: Pro Evolution Soccer 2007 (All...     X360
# 2373  2375                           Phantasy Star Portable 2      PSP
# 2579  2581                               The Sims 2: Castaway      PSP
# 3186  3188                                     SingStar Queen      PS2
# 3503  3505                                         Top Spin 3      PS3
# 3703  3705               Sonic & All-Stars Racing Transformed      PS3
#
#         Year         Genre                     Publisher  NA_Sales  EU_Sales  \
# 446   1990.0  Role-Playing              Enix Corporation      0.08      0.00
# ...

# %% [markdown]
# ## 6- For the top-selling game of all time, how many standard deviations above/below the mean are its sales for North America?

# %%
df_NA=df['NA_Sales']
mean_NA = df_NA.mean()
std_NA = df_NA.std()
max_NA = df_NA.max()
z = (max_NA - mean_NA)/std_NA
z
# Out:
# 50.47898767479108

# %% [markdown]
# ## 7-The Nintendo Wii seems to have outdone itself with games. How does its average number of sales compare with all of the other platforms?

# %%
wii =df[df['Platform']=='Wii']
other=df[df['Platform'] != 'Wii']
result=(other["Global_Sales"].mean(),wii["Global_Sales"].mean())
result
# Out:
# (0.5233896418516336, 0.6994037735849057)

# %% [markdown]
# ## 8- Come up with 3 more questions that can be answered with this data set.

# %% [markdown]
# ### Top Rank in 2000

# %%
top_2000 = df[df['Year'] == 2000].sort_values('Rank').head(1)
top_2000
# Out:
#      Rank                     Name Platform    Year         Genre Publisher  \
# 132   133  Pokémon Crystal Version       GB  2000.0  Role-Playing  Nintendo
#
#      NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 132      2.55      1.56      1.29         0.99          6.39

# %% [markdown]
# ### what is the games in pc platform ?

# %%
pc_platform = df[df['Platform']=='PC']
pc_platform
# Out:
#         Rank                            Name Platform    Year         Genre  \
# 83        84                      The Sims 3       PC  2009.0    Simulation
# 137      138               World of Warcraft       PC  2004.0  Role-Playing
# 181      182                      Diablo III       PC  2012.0  Role-Playing
# 194      195      Microsoft Flight Simulator       PC  1996.0    Simulation
# 217      218  StarCraft II: Wings of Liberty       PC  2010.0      Strategy
# ...      ...                             ...      ...     ...           ...
# 16558  16561       Pro Evolution Soccer 2008       PC  2007.0        Sports
# 16566  16569                  End of Nations       PC  2012.0      Strategy
# 16577  16580                       Damnation       PC  2009.0       Shooter
# 16585  16588                          Breach       PC  2011.0       Shooter
# 16591  16594             Myst IV: Revelation       PC  2004.0     Adventure
#
# ...

# %% [markdown]
# ### what is the last 20 ranks ?

# %%
last_10_ranks=df.tail(10)
last_10_ranks
# Out:
#         Rank                                               Name Platform  \
# 16588  16591                                   Mega Brain Boost       DS
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
# 16590  16593  Eiyuu Densetsu: Sora no Kiseki Material Collec...      PSP
# 16591  16594                                Myst IV: Revelation       PC
# 16592  16595                                           Plushees       DS
# 16593  16596                 Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                      Men in Black II: Alien Escape       GC
# 16595  16598   SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                         Know How 2       DS
# 16597  16600                                   Spirits & Spells      GBA
#
#          Year         Genre              Publisher  NA_Sales  EU_Sales  \
# 16588  2008.0        Puzzle  Majesco Entertainment      0.01      0.00
# ...

# %%
def test():

    def assert_equal(actual,expected):
        assert actual == expected, f"Expected {expected} but got {actual}"

    assert_equal(most_publisher, 'Electronic Arts')
    assert_equal(most_paltform, 'DS')
    assert_equal(most_Genre, 'Action')
    assert_equal(highest_grossing.iloc[0].Name, 'Wii Sports')
    assert_equal(top_ten.iloc[0].Name, 'Dragon Warrior IV')
    assert_equal(z, 50.47898767479108)
    assert_equal(result, (0.5233896418516336, 0.6994037735849057))

    print("Success!!!")

test()
# Out:
# Success!!!
